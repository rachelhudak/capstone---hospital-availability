# %%
import pandas as pd

# %%
hospitals = pd.read_csv("Data/cleaned_tennessee_hospitals_v2 (1).csv")

# %%
hospitals.head()
# Out:
#   facility_id                                      facility_name   city_town  \
# 0      440002            JACKSON-MADISON COUNTY GENERAL HOSPITAL     Jackson
# 1      440003  HIGHPOINT HEALTH-SUMNER WITH ASCENSION SAINT T...    Gallatin
# 2      440006                     TRISTAR SKYLINE MEDICAL CENTER   Nashville
# 3      440007                               UNITY MEDICAL CENTER  Manchester
# 4      440008                HENDERSON COUNTY COMMUNITY HOSPITAL   Lexington
#
#   state  zip_code         hospital_type  \
# 0    TN     38301  Acute Care Hospitals
# 1    TN     37066  Acute Care Hospitals
# 2    TN     37207  Acute Care Hospitals
# 3    TN     37355  Acute Care Hospitals
# 4    TN     38351  Acute Care Hospitals
#
#                             hospital_ownership emergency_services  \
# 0  Government - Hospital District Or Authority                Yes
# 1                                  Proprietary                Yes
# ...

# %%
income = pd.read_csv("Data/cleaned_pulse_data.csv")

# %%
income.head()
# Out:
#            County     FIPS  Value (Dollars) Rank within US (of 3139 counties)
# 0       Tennessee  47000.0          84212.0                          42 of 52
# 1   United States      0.0          96922.0                               NaN
# 2     Lake County  47095.0          39522.0                              3127
# 3  Hancock County  47067.0          48165.0                              3092
# 4   Grundy County  47061.0          52772.0                              3029
